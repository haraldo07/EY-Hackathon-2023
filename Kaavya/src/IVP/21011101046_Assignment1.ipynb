# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_excel('RollCall.xlsx')
df.head()
# Out:
#    REGISTRATION NUMBER              NAME
# 0          21011101001       A ABHIRAMEE
# 1          21011101002      A AKASH IYER
# 2          21011101003          AAKASH S
# 3          21011101004       ABARAJITH S
# 4          21011101005  ABDULLAH SHERIFF

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   REGISTRATION NUMBER  72 non-null     int64
#  1   NAME                 72 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 1.3+ KB

# %%
height_values = ['5.4', '5.6', '5.8', '5.10', '6']
weight_values = [50, 60, 65, 70, 75]
height_data = np.array(np.random.choice(height_values, 72), dtype=float)
weight_data = np.array(np.random.choice(weight_values, 72), dtype=float)

# %%
df['Weight']=weight_data
df['Height']=height_data

# %%
df.head()
# Out:
#    REGISTRATION NUMBER              NAME  Weight  Height
# 0          21011101001       A ABHIRAMEE    70.0     5.4
# 1          21011101002      A AKASH IYER    65.0     5.8
# 2          21011101003          AAKASH S    70.0     5.4
# 3          21011101004       ABARAJITH S    50.0     5.1
# 4          21011101005  ABDULLAH SHERIFF    75.0     5.4

# %%
plt.figure(figsize=(5, 3))
sns.jointplot(x='Height', y='Weight', data=df.iloc[:,[2,3]], kind='hex')
plt.show()

# %%
plt.figure(figsize=(5, 3))
sns.jointplot(x='Height', y='Weight', data=df.iloc[:,[2,3]], kind='reg')
plt.show()

# %%
plt.figure(figsize=(5, 3))
sns.jointplot(x='Height', y='Weight', data=df.iloc[:,[2,3]], kind='hist')
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.hist(height_data, bins=len(height_values), edgecolor='black',color='green', alpha=0.7)
plt.title('Height Distribution')
plt.xlabel('Height (ft)')
plt.ylabel('Frequency')

plt.subplot(1, 2, 2)
plt.hist(weight_data, bins=len(weight_values), edgecolor='black', color='pink', alpha=0.7)
plt.title('Weight Distribution')
plt.xlabel('Weight (kg)')
plt.ylabel('Frequency')

plt.show()

# %%
print('\033[1m'+'\033[96m'+"Statistical Inference of Height"+'\033[0m \n\n')
print("Mean:",df['Height'].mean())
print("Median:",df['Height'].median())
print("Mode:",df['Height'].mode()[0])
print("Standard Deviation:",df['Height'].std())
print("Variance:",df['Height'].var())
print("Skew:",df['Height'].skew())
print("Kurtosis:",df['Height'].kurtosis())
# Out:
# Statistical Inference of Height
#
#
# Mean: 5.519444444444444
# Median: 5.5
# Mode: 5.1
# Standard Deviation: 0.3138308905382404
# Variance: 0.09848982785602503
# Skew: 0.06259808314814296
# Kurtosis: -1.1997163454958457

# %%
print('\033[1m'+'\033[92m'+"Statistical Inference of Weight"+'\033[0m \n\n')
print("Mean:",df['Weight'].mean())
print("Median:",df['Weight'].median())
print("Mode:",df['Weight'].mode()[0])
print("Standard Deviation:",df['Weight'].std())
print("Variance:",df['Weight'].var())
print("Skew:",df['Weight'].skew())
print("Kurtosis:",df['Weight'].kurtosis())
# Out:
# Statistical Inference of Weight
#
#
# Mean: 64.09722222222223
# Median: 65.0
# Mode: 75.0
# Standard Deviation: 9.128441426634623
# Variance: 83.32844287949915
# Skew: -0.38183131616206895
# Kurtosis: -1.1378589653267204
